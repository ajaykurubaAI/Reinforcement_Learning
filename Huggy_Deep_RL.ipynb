# %%
# Clone the repository (can take 3min)
# !git clone --depth 1 https://github.com/Unity-Technologies/ml-agents
# Out:
# Cloning into 'ml-agents'...
# remote: Enumerating objects: 2338, done.
# remote: Counting objects: 100% (2338/2338), done.
# remote: Compressing objects: 100% (1920/1920), done.
# remote: Total 2338 (delta 878), reused 1150 (delta 398), pack-reused 0
# Receiving objects: 100% (2338/2338), 97.01 MiB | 24.90 MiB/s, done.
# Resolving deltas: 100% (878/878), done.
# Updating files: 100% (2169/2169), done.

# %%
# %cd ml-agents
# Out:
# /content/ml-agents

# %%
# !pip3 install -e ./ml-agents-envs
# !pip3 install -e ./ml-agents
# Out:
# Obtaining file:///content/ml-agents/ml-agents-envs
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.31.0.dev0) (2.2.1)
# Requirement already satisfied: grpcio>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.31.0.dev0) (1.56.0)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.31.0.dev0) (8.4.0)
# Collecting protobuf<3.20,>=3.6 (from mlagents-envs==0.31.0.dev0)
#   Downloading protobuf-3.19.6-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 28.4 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.31.0.dev0) (6.0)
# Requirement already satisfied: gym>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.31.0.dev0) (0.25.2)
# Collecting pettingzoo==1.15.0 (from mlagents-envs==0.31.0.dev0)
#   Downloading PettingZoo-1.15.0.tar.gz (756 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.7/756.7 kB 51.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting numpy==1.21.2 (from mlagents-envs==0.31.0.dev0)
#   Downloading numpy-1.21.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (15.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.9/15.9 MB 67.2 MB/s eta 0:00:00
# Requirement already satisfied: filelock>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from mlagents-envs==0.31.0.dev0) (3.12.2)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.21.0->mlagents-envs==0.31.0.dev0) (0.0.8)
# Building wheels for collected packages: pettingzoo
#   Building wheel for pettingzoo (setup.py) ... done
#   Created wheel for pettingzoo: filename=PettingZoo-1.15.0-py3-none-any.whl size=875639 sha256=e99159f6c94239e7ea7fd962cdf4c9c757fb9a7ffcd1604246e02e9cda245af9
#   Stored in directory: /root/.cache/pip/wheels/e3/35/ac/76984cb1c12902d190c818d57c43d25c3f9281591a640ccd13
# Successfully built pettingzoo
# Installing collected packages: protobuf, numpy, pettingzoo, mlagents-envs
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 3.20.3
#     Uninstalling protobuf-3.20.3:
#       Successfully uninstalled protobuf-3.20.3
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.22.4
#     Uninstalling numpy-1.22.4:
#       Successfully uninstalled numpy-1.22.4
#   Running setup.py develop for mlagents-envs
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.12.0 requires numpy<1.24,>=1.22, but you have numpy 1.21.2 which is incompatible.
# tensorflow 2.12.0 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-datasets 4.9.2 requires protobuf>=3.20, but you have protobuf 3.19.6 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 3.19.6 which is incompatible.
# Successfully installed mlagents-envs-0.31.0.dev0 numpy-1.21.2 pettingzoo-1.15.0 protobuf-3.19.6
# Obtaining file:///content/ml-agents/ml-agents
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: grpcio>=1.11.0 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (1.56.0)
# Requirement already satisfied: h5py>=2.9.0 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (3.8.0)
# Requirement already satisfied: mlagents_envs==0.31.0.dev0 in ./ml-agents-envs (from mlagents==0.31.0.dev0) (0.31.0.dev0)
# Requirement already satisfied: numpy<2.0,>=1.13.3 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (1.21.2)
# Requirement already satisfied: Pillow>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (8.4.0)
# Requirement already satisfied: protobuf<3.20,>=3.6 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (3.19.6)
# Requirement already satisfied: pyyaml>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (6.0)
# Requirement already satisfied: tensorboard>=1.15 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (2.12.3)
# Requirement already satisfied: attrs>=19.3.0 in /usr/local/lib/python3.10/dist-packages (from mlagents==0.31.0.dev0) (23.1.0)
# Collecting huggingface_hub>=0.14 (from mlagents==0.31.0.dev0)
#   Downloading huggingface_hub-0.16.4-py3-none-any.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 13.4 MB/s eta 0:00:00
# Collecting torch<=1.11.0,>=1.8.0 (from mlagents==0.31.0.dev0)
#   Downloading torch-1.11.0-cp310-cp310-manylinux1_x86_64.whl (750.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 750.6/750.6 MB 2.3 MB/s eta 0:00:00
# Collecting cattrs<1.7,>=1.1.0 (from mlagents==0.31.0.dev0)
#   Downloading cattrs-1.5.0-py3-none-any.whl (19 kB)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.10/dist-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (2.2.1)
# Requirement already satisfied: gym>=0.21.0 in /usr/local/lib/python3.10/dist-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (0.25.2)
# Requirement already satisfied: pettingzoo==1.15.0 in /usr/local/lib/python3.10/dist-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (1.15.0)
# Requirement already satisfied: filelock>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (3.12.2)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2023.6.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2.27.1)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (4.65.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (4.7.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from huggingface_hub>=0.14->mlagents==0.31.0.dev0) (23.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (1.4.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (2.17.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (3.4.3)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (67.7.2)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (0.7.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (2.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.10/dist-packages (from tensorboard>=1.15->mlagents==0.31.0.dev0) (0.40.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (5.3.1)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (0.3.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (1.16.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.10/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->mlagents==0.31.0.dev0) (1.3.1)
# Requirement already satisfied: gym-notices>=0.0.4 in /usr/local/lib/python3.10/dist-packages (from gym>=0.21.0->mlagents_envs==0.31.0.dev0->mlagents==0.31.0.dev0) (0.0.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2023.5.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (2.0.12)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->huggingface_hub>=0.14->mlagents==0.31.0.dev0) (3.4)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /usr/local/lib/python3.10/dist-packages (from werkzeug>=1.0.1->tensorboard>=1.15->mlagents==0.31.0.dev0) (2.1.3)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in /usr/local/lib/python3.10/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=1.15->mlagents==0.31.0.dev0) (0.5.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.10/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=1.15->mlagents==0.31.0.dev0) (3.2.2)
# Installing collected packages: torch, cattrs, huggingface_hub, mlagents
#   Attempting uninstall: torch
#     Found existing installation: torch 2.0.1+cu118
#     Uninstalling torch-2.0.1+cu118:
#       Successfully uninstalled torch-2.0.1+cu118
#   Running setup.py develop for mlagents
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.0.2+cu118 requires torch==2.0.1, but you have torch 1.11.0 which is incompatible.
# torchdata 0.6.1 requires torch==2.0.1, but you have torch 1.11.0 which is incompatible.
# torchtext 0.15.2 requires torch==2.0.1, but you have torch 1.11.0 which is incompatible.
# torchvision 0.15.2+cu118 requires torch==2.0.1, but you have torch 1.11.0 which is incompatible.
# Successfully installed cattrs-1.5.0 huggingface_hub-0.16.4 mlagents-0.31.0.dev0 torch-1.11.0

# %%
# !mkdir ./trained-envs-executables
# !mkdir ./trained-envs-executables/linux

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF" -O ./trained-envs-executables/linux/Huggy.zip && rm -rf /tmp/cookies.txt
# Out:
# --2023-07-17 09:52:17--  https://docs.google.com/uc?export=download&confirm=t&id=1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF
# Resolving docs.google.com (docs.google.com)... 142.250.153.138, 142.250.153.101, 142.250.153.100, ...
# Connecting to docs.google.com (docs.google.com)|142.250.153.138|:443... connected.
# HTTP request sent, awaiting response... 303 See Other
# Location: https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/06h6635b01fea3lcpi3747816lsd18a0/1689587475000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=125de9ce-b5c8-451e-a140-60aef26dc23b [following]
# Warning: wildcards not supported in HTTP.
# --2023-07-17 09:52:17--  https://doc-0k-28-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/06h6635b01fea3lcpi3747816lsd18a0/1689587475000/15803371278684422230/*/1zv3M95ZJTWHUVOWT6ckq_cm98nft8gdF?e=download&uuid=125de9ce-b5c8-451e-a140-60aef26dc23b
# Resolving doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)... 108.177.119.132, 2a00:1450:4013:c00::84
# Connecting to doc-0k-28-docs.googleusercontent.com (doc-0k-28-docs.googleusercontent.com)|108.177.119.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 39214997 (37M) [application/x-zip-compressed]
# Saving to: ‘./trained-envs-executables/linux/Huggy.zip’
#
# ./trained-envs-exec 100%[===================>]  37.40M  67.8MB/s    in 0.6s
#
# 2023-07-17 09:52:18 (67.8 MB/s) - ‘./trained-envs-executables/linux/Huggy.zip’ saved [39214997/39214997]

# %%
# %%capture
# !unzip -d ./trained-envs-executables/linux/ ./trained-envs-executables/linux/Huggy.zip

# %%
# !ls
# Out:
# CODE_OF_CONDUCT.md		ml-agents-envs
# colab				ml-agents-plugin-examples
# colab_requirements.txt		ml-agents-trainer-plugin
# com.unity.ml-agents		Project
# com.unity.ml-agents.extensions	protobuf-definitions
# config				pytest.ini
# conftest.py			setup.cfg
# DevProject			SURVEY.md
# Dockerfile			test_constraints_max_version.txt
# docs				test_constraints_mid_version.txt
# LICENSE.md			test_constraints_min_version.txt
# localized_docs			test_requirements.txt
# markdown-link-check.fast.json	trained-envs-executables
# markdown-link-check.full.json	unity-volume
# mkdocs.yml			utils
# ml-agents

# %%
# !chmod -R 755 trained-envs-executables/linux/Huggy

# %%
# !mlagents-learn ./config/ppo/Huggy.yaml --env=./trained-envs-executables/linux/Huggy/Huggy --run-id="Huggy" --no-graphics
# Out:
#             ┐  ╖
#         ╓╖╬│╡  ││╬╖╖
#     ╓╖╬│││││┘  ╬│││││╬╖
#  ╖╬│││││╬╜        ╙╬│││││╖╖                               ╗╗╗
#  ╬╬╬╬╖││╦╖        ╖╬││╗╣╣╣╬      ╟╣╣╬    ╟╣╣╣             ╜╜╜  ╟╣╣
#  ╬╬╬╬╬╬╬╬╖│╬╖╖╓╬╪│╓╣╣╣╣╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╒╣╣╖╗╣╣╣╗   ╣╣╣ ╣╣╣╣╣╣ ╟╣╣╖   ╣╣╣
#  ╬╬╬╬┐  ╙╬╬╬╬│╓╣╣╣╝╜  ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╣╙ ╙╣╣╣  ╣╣╣ ╙╟╣╣╜╙  ╫╣╣  ╟╣╣
#  ╬╬╬╬┐     ╙╬╬╣╣      ╫╣╣╣╬      ╟╣╣╬    ╟╣╣╣ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣     ╣╣╣┌╣╣╜
#  ╬╬╬╜       ╬╬╣╣      ╙╝╣╣╬      ╙╣╣╣╗╖╓╗╣╣╣╜ ╟╣╣╬   ╣╣╣  ╣╣╣  ╟╣╣╦╓    ╣╣╣╣╣
#  ╙   ╓╦╖    ╬╬╣╣   ╓╗╗╖            ╙╝╣╣╣╣╝╜   ╘╝╝╜   ╝╝╝  ╝╝╝   ╙╣╣╣    ╟╣╣╣
#    ╩╬╬╬╬╬╬╦╦╬╬╣╣╗╣╣╣╣╣╣╣╝                                             ╫╣╣╣╣
#       ╙╬╬╬╬╬╬╬╣╣╣╣╣╣╝╜
#           ╙╬╬╬╣╣╣╜
#              ╙
#
#  Version information:
#   ml-agents: 0.31.0.dev0,
#   ml-agents-envs: 0.31.0.dev0,
#   Communicator API: 1.5.0,
#   PyTorch: 1.11.0+cu102
# [INFO] Connected to Unity environment with package version 2.2.1-exp.1 and communication version 1.5.0
# [INFO] Connected new brain: Huggy?team=0
# 2023-07-17 09:57:42.638145: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# [INFO] Hyperparameters for behavior name Huggy:
# 	trainer_type:	ppo
# 	hyperparameters:
# 	  batch_size:	2048
# 	  buffer_size:	20480
# 	  learning_rate:	0.0003
# 	  beta:	0.005
# 	  epsilon:	0.2
# 	  lambd:	0.95
# 	  num_epoch:	3
# 	  shared_critic:	False
# 	  learning_rate_schedule:	linear
# 	  beta_schedule:	linear
# 	  epsilon_schedule:	linear
# 	checkpoint_interval:	200000
# 	network_settings:
# 	  normalize:	True
# 	  hidden_units:	512
# 	  num_layers:	3
# 	  vis_encode_type:	simple
# 	  memory:	None
# 	  goal_conditioning_type:	hyper
# 	  deterministic:	False
# 	reward_signals:
# 	  extrinsic:
# 	    gamma:	0.995
# 	    strength:	1.0
# 	    network_settings:
# 	      normalize:	False
# 	      hidden_units:	128
# 	      num_layers:	2
# 	      vis_encode_type:	simple
# 	      memory:	None
# 	      goal_conditioning_type:	hyper
# 	      deterministic:	False
# 	init_path:	None
# 	keep_checkpoints:	15
# 	even_checkpoints:	False
# 	max_steps:	2000000
# 	time_horizon:	1000
# 	summary_freq:	50000
# 	threaded:	False
# 	self_play:	None
# 	behavioral_cloning:	None
# [INFO] Huggy. Step: 50000. Time Elapsed: 73.079 s. Mean Reward: 1.798. Std of Reward: 0.871. Training.
# [INFO] Huggy. Step: 100000. Time Elapsed: 135.690 s. Mean Reward: 2.550. Std of Reward: 1.057. Training.
# [INFO] Huggy. Step: 150000. Time Elapsed: 203.597 s. Mean Reward: 3.044. Std of Reward: 1.211. Training.
# [INFO] Huggy. Step: 200000. Time Elapsed: 267.151 s. Mean Reward: 3.430. Std of Reward: 1.285. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-199921.onnx
# [INFO] Huggy. Step: 250000. Time Elapsed: 334.174 s. Mean Reward: 3.495. Std of Reward: 1.372. Training.
# [INFO] Huggy. Step: 300000. Time Elapsed: 399.568 s. Mean Reward: 3.609. Std of Reward: 1.620. Training.
# [INFO] Huggy. Step: 350000. Time Elapsed: 462.601 s. Mean Reward: 3.938. Std of Reward: 1.837. Training.
# [INFO] Huggy. Step: 400000. Time Elapsed: 534.474 s. Mean Reward: 3.688. Std of Reward: 1.757. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-399995.onnx
# [INFO] Huggy. Step: 450000. Time Elapsed: 599.266 s. Mean Reward: 3.705. Std of Reward: 1.895. Training.
# [INFO] Huggy. Step: 500000. Time Elapsed: 666.973 s. Mean Reward: 3.704. Std of Reward: 1.903. Training.
# [INFO] Huggy. Step: 550000. Time Elapsed: 732.830 s. Mean Reward: 3.730. Std of Reward: 1.843. Training.
# [INFO] Huggy. Step: 600000. Time Elapsed: 802.164 s. Mean Reward: 3.778. Std of Reward: 1.725. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-599865.onnx
# [INFO] Huggy. Step: 650000. Time Elapsed: 867.912 s. Mean Reward: 3.744. Std of Reward: 1.790. Training.
# [INFO] Huggy. Step: 700000. Time Elapsed: 932.845 s. Mean Reward: 3.758. Std of Reward: 1.718. Training.
# [INFO] Huggy. Step: 750000. Time Elapsed: 1003.346 s. Mean Reward: 3.840. Std of Reward: 1.695. Training.
# [INFO] Huggy. Step: 800000. Time Elapsed: 1067.551 s. Mean Reward: 3.724. Std of Reward: 1.819. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-799921.onnx
# [INFO] Huggy. Step: 850000. Time Elapsed: 1136.155 s. Mean Reward: 3.793. Std of Reward: 1.865. Training.
# [INFO] Huggy. Step: 900000. Time Elapsed: 1201.480 s. Mean Reward: 3.822. Std of Reward: 1.814. Training.
# [INFO] Huggy. Step: 950000. Time Elapsed: 1272.976 s. Mean Reward: 3.930. Std of Reward: 1.866. Training.
# [INFO] Huggy. Step: 1000000. Time Elapsed: 1336.932 s. Mean Reward: 3.714. Std of Reward: 1.913. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-999955.onnx
# [INFO] Huggy. Step: 1050000. Time Elapsed: 1403.161 s. Mean Reward: 3.785. Std of Reward: 1.896. Training.
# [INFO] Huggy. Step: 1100000. Time Elapsed: 1473.507 s. Mean Reward: 3.787. Std of Reward: 1.753. Training.
# [INFO] Huggy. Step: 1150000. Time Elapsed: 1539.637 s. Mean Reward: 3.766. Std of Reward: 1.911. Training.
# [INFO] Huggy. Step: 1200000. Time Elapsed: 1608.196 s. Mean Reward: 3.907. Std of Reward: 1.972. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1199394.onnx
# [INFO] Huggy. Step: 1250000. Time Elapsed: 1675.448 s. Mean Reward: 3.783. Std of Reward: 1.964. Training.
# [INFO] Huggy. Step: 1300000. Time Elapsed: 1747.569 s. Mean Reward: 3.729. Std of Reward: 1.951. Training.
# [INFO] Huggy. Step: 1350000. Time Elapsed: 1811.415 s. Mean Reward: 3.684. Std of Reward: 1.979. Training.
# [INFO] Huggy. Step: 1400000. Time Elapsed: 1878.183 s. Mean Reward: 3.906. Std of Reward: 1.935. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1399938.onnx
# [INFO] Huggy. Step: 1450000. Time Elapsed: 1950.606 s. Mean Reward: 3.800. Std of Reward: 1.851. Training.
# [INFO] Huggy. Step: 1500000. Time Elapsed: 2016.240 s. Mean Reward: 3.754. Std of Reward: 1.966. Training.
# [INFO] Huggy. Step: 1550000. Time Elapsed: 2088.293 s. Mean Reward: 3.879. Std of Reward: 1.992. Training.
# [INFO] Huggy. Step: 1600000. Time Elapsed: 2158.408 s. Mean Reward: 3.831. Std of Reward: 1.895. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1599944.onnx
# [INFO] Huggy. Step: 1650000. Time Elapsed: 2228.873 s. Mean Reward: 3.818. Std of Reward: 1.941. Training.
# [INFO] Huggy. Step: 1700000. Time Elapsed: 2296.293 s. Mean Reward: 3.814. Std of Reward: 1.998. Training.
# [INFO] Huggy. Step: 1750000. Time Elapsed: 2366.421 s. Mean Reward: 3.790. Std of Reward: 1.930. Training.
# [INFO] Huggy. Step: 1800000. Time Elapsed: 2438.147 s. Mean Reward: 3.678. Std of Reward: 1.789. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1799951.onnx
# [INFO] Huggy. Step: 1850000. Time Elapsed: 2506.690 s. Mean Reward: 3.827. Std of Reward: 1.990. Training.
# [INFO] Huggy. Step: 1900000. Time Elapsed: 2578.649 s. Mean Reward: 3.730. Std of Reward: 1.896. Training.
# [INFO] Huggy. Step: 1950000. Time Elapsed: 2648.908 s. Mean Reward: 3.885. Std of Reward: 1.936. Training.
# [INFO] Huggy. Step: 2000000. Time Elapsed: 2719.190 s. Mean Reward: 3.942. Std of Reward: 1.966. Training.
# [INFO] Exported results/Huggy/Huggy/Huggy-1999888.onnx
# [INFO] Exported results/Huggy/Huggy/Huggy-2000013.onnx
# [INFO] Copied results/Huggy/Huggy/Huggy-2000013.onnx to results/Huggy/Huggy.onnx.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
# !mlagents-push-to-hf --run-id="HuggyTraining" --local-dir="./results/Huggy" --repo-id="ajaycompete143/ppo-Huggy" --commit-message="Huggy"
# Out:
# [INFO] This function will create a model card and upload your HuggyTraining into HuggingFace Hub. This is a work in progress: If you encounter a bug, please send open an issue
# [INFO] Pushing repo HuggyTraining to the Hugging Face Hub
# Huggy-1199394.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
# Huggy-1199394.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
# Huggy-1399938.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
# Huggy-1399938.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
# Huggy-1599944.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Upload 25 LFS files:   0% 0/25 [00:00<?, ?it/s]
#
# Huggy-1399938.pt:   0% 8.19k/13.5M [00:00<08:00, 28.1kB/s]
#
#
# Huggy-1199394.pt:   0% 8.19k/13.5M [00:00<08:13, 27.3kB/s]
# Huggy-1199394.onnx:   0% 8.19k/2.27M [00:00<01:22, 27.4kB/s]
#
#
#
# Huggy-1599944.onnx:   0% 8.19k/2.27M [00:00<01:20, 28.0kB/s]
#
# Huggy-1399938.pt:   1% 180k/13.5M [00:00<00:28, 472kB/s]
#
#
# Huggy-1199394.pt:   1% 180k/13.5M [00:00<00:28, 464kB/s]
# Huggy-1199394.onnx:   8% 180k/2.27M [00:00<00:04, 466kB/s]
#
#
#
# Huggy-1599944.onnx:   8% 180k/2.27M [00:00<00:04, 471kB/s]
#
# Huggy-1399938.pt:   4% 508k/13.5M [00:00<00:12, 1.04MB/s]
#
#
# Huggy-1199394.pt:   4% 590k/13.5M [00:00<00:10, 1.21MB/s]
# Huggy-1199394.onnx:  24% 541k/2.27M [00:00<00:01, 1.10MB/s]
#
#
#
# Huggy-1599944.onnx:  22% 500k/2.27M [00:00<00:01, 1.02MB/s]
#
# Huggy-1399938.pt:  14% 1.86M/13.5M [00:00<00:03, 3.85MB/s]
#
#
# Huggy-1199394.pt:  12% 1.69M/13.5M [00:00<00:03, 3.04MB/s]
# Huggy-1199394.onnx:  94% 2.14M/2.27M [00:00<00:00, 3.98MB/s]
#
# Huggy-1399938.onnx: 100% 2.27M/2.27M [00:01<00:00, 2.12MB/s]
# Huggy-1199394.pt:  40% 5.38M/13.5M [00:01<00:01, 7.81MB/s]
#
# Huggy-1599944.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.94MB/s]
# Huggy-1199394.onnx: 100% 2.27M/2.27M [00:01<00:00, 1.91MB/s]
#
#
# Huggy-1399938.pt:  72% 9.70M/13.5M [00:01<00:00, 12.9MB/s]
# Huggy-1199394.pt:  80% 10.8M/13.5M [00:01<00:00, 15.2MB/s]
#
#
#
#
# Upload 25 LFS files:   4% 1/25 [00:01<00:32,  1.37s/it]
#
#
# Huggy-1799951.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
# Huggy-1799951.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
# Huggy-1199394.pt: 100% 13.5M/13.5M [00:01<00:00, 8.76MB/s]
# Huggy-1399938.pt: 100% 13.5M/13.5M [00:01<00:00, 8.64MB/s]
#
# Huggy-1599944.pt:  64% 8.62M/13.5M [00:00<00:00, 32.1MB/s]
#
#
#
# Huggy-1799951.onnx: 100% 2.27M/2.27M [00:00<00:00, 8.96MB/s]
#
# Huggy-1599944.pt:  91% 12.3M/13.5M [00:00<00:00, 33.7MB/s]
#
#
#
# Huggy-199921.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
#
#
# Upload 25 LFS files:   8% 2/25 [00:01<00:18,  1.22it/s]
#
# Huggy-199921.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
# Huggy-1599944.pt: 100% 13.5M/13.5M [00:00<00:00, 21.6MB/s]
#
# Huggy-1999888.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
# Huggy-199921.onnx: 100% 2.27M/2.27M [00:00<00:00, 9.67MB/s]
#
#
# Huggy-1799951.pt: 100% 13.5M/13.5M [00:00<00:00, 21.6MB/s]
#
#
#
#
#
# Huggy-1999888.onnx: 100% 2.27M/2.27M [00:00<00:00, 13.6MB/s]
#
#
# Huggy-1999888.pt:  29% 3.98M/13.5M [00:00<00:00, 39.8MB/s]
# Huggy.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
#
# checkpoint.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
#
# Upload 25 LFS files:  32% 8/25 [00:02<00:03,  5.64it/s]
#
#
#
# Huggy-1999888.pt:  63% 8.54M/13.5M [00:00<00:00, 42.4MB/s]
#
#
# Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 13.1MB/s]
# Huggy-199921.pt: 100% 13.5M/13.5M [00:00<00:00, 24.2MB/s]
# Huggy-399995.onnx: 100% 2.27M/2.27M [00:00<00:00, 12.2MB/s]
#
#
#
# Huggy-1999888.pt:  95% 12.8M/13.5M [00:00<00:00, 32.0MB/s]
# Huggy-399995.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
# Huggy-599865.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
# Huggy-1999888.pt: 100% 13.5M/13.5M [00:00<00:00, 25.5MB/s]
#
#
#
# checkpoint.pt:  93% 12.6M/13.5M [00:00<00:00, 30.6MB/s]
# Huggy-599865.pt:   0% 0.00/13.5M [00:00<?, ?B/s]
#
#
#
#
# Upload 25 LFS files:  40% 10/25 [00:02<00:03,  4.91it/s]
#
#
#
# checkpoint.pt: 100% 13.5M/13.5M [00:00<00:00, 24.3MB/s]
#
# Huggy-599865.onnx: 100% 2.27M/2.27M [00:00<00:00, 8.13MB/s]
# Huggy-799921.onnx: 100% 2.27M/2.27M [00:00<00:00, 11.3MB/s]
#
#
#
#
#
# Upload 25 LFS files:  56% 14/25 [00:02<00:01,  7.59it/s]
#
# Huggy-599865.pt:  67% 9.06M/13.5M [00:00<00:00, 33.7MB/s]
#
#
# Huggy-999955.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
#
# Huggy-399995.pt: 100% 13.5M/13.5M [00:00<00:00, 23.4MB/s]
#
# Huggy-999955.onnx: 100% 2.27M/2.27M [00:00<00:00, 14.6MB/s]
#
#
# Huggy-799921.pt:  62% 8.32M/13.5M [00:00<00:00, 41.5MB/s]
# Huggy-999955.pt:  31% 4.22M/13.5M [00:00<00:00, 42.2MB/s]
#
#
#
#
# Upload 25 LFS files:  64% 16/25 [00:03<00:01,  7.29it/s]
#
#
# Huggy-599865.pt: 100% 13.5M/13.5M [00:00<00:00, 24.9MB/s]
# events.out.tfevents.1689587862.d53456fd7140.4541.0:   0% 0.00/381k [00:00<?, ?B/s]
# Huggy-999955.pt:  62% 8.44M/13.5M [00:00<00:00, 41.3MB/s]
#
# Huggy-799921.pt:  92% 12.5M/13.5M [00:00<00:00, 31.7MB/s]
#
#
# checkpoint.pt:  29% 3.87M/13.5M [00:00<00:00, 38.7MB/s]
#
#
#
#
# Upload 25 LFS files:  72% 18/25 [00:03<00:00,  8.48it/s]
#
#
#
# Huggy.onnx:   0% 0.00/2.27M [00:00<?, ?B/s]
# Huggy-999955.pt:  93% 12.6M/13.5M [00:00<00:00, 40.2MB/s]
#
#
# events.out.tfevents.1689587862.d53456fd7140.4541.0: 100% 381k/381k [00:00<00:00, 2.12MB/s]
# Huggy-799921.pt: 100% 13.5M/13.5M [00:00<00:00, 22.9MB/s]
# Huggy.onnx: 100% 2.27M/2.27M [00:00<00:00, 10.9MB/s]
# Huggy-999955.pt: 100% 13.5M/13.5M [00:00<00:00, 25.3MB/s]
#
#
#
#
#
# checkpoint.pt: 100% 13.5M/13.5M [00:00<00:00, 24.7MB/s]
#
#
#
#
#
# Upload 25 LFS files: 100% 25/25 [00:03<00:00,  6.43it/s]
# [INFO] Your model is pushed to the hub. You can view your model here: https://huggingface.co/ajaycompete143/ppo-Huggy
